# %% [markdown]
# <a href="https://colab.research.google.com/github/elango-ela/YOLOv8-Fine-tuning-for-PCB-Board-Defect-Detection/blob/main/yolo_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Roboflow Auth

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="keLnYV1gi59z3aBkUxfz")
project = rf.workspace("classytamil").project("pcb-component-detection2")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 90.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 131.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pcb-component-detection2-3 in yolov8:: 100%|██████████| 8786/8786 [00:01<00:00, 6760.16it/s]

# %% [markdown]
# ## Train Yolo Model

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.2 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model.train(data="/content/pcb-component-detection2-3/data.yaml", epochs=70, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## Test The Model

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

res = model.val(data="/content/pcb-component-detection2-3/data.yaml")
print(res)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,793 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1022.0±346.6 MB/s, size: 59.4 KB)
# val: Scanning /content/pcb-component-detection2-3/valid/labels.cache... 375 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 375/375 334.9Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 12, len(boxes) = 3339. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 3.9it/s 6.1s
#                    all        375       3339      0.938      0.993       0.97      0.648
#          1002-resistor        331        331      0.984      0.988      0.991      0.602
# ...
